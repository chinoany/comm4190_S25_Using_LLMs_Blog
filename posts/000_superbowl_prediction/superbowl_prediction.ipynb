# %% [raw]
# ---
# title: "ChatGPT predicted the Eagles would win... and they did!"
# description: "Go Birds!"
# author: "An LLM User"
# date: "2/2/2024"
# categories:
#   - LLMs
#   - Current Trends
# ---

# %% [markdown]
# this is my blog

# %% [markdown]
# ![Screenshot 2025-02-03 at 4.20.28 PM.png](attachment:8d964fcf-926a-46a3-a374-1b1e98fa2515.png)
